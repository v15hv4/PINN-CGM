# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from utils import dt2int

from collections import namedtuple
from datetime import timedelta, datetime

from simglucose.patient.t1dpatient import T1DPatient

from simglucose.sensor.cgm import CGMSensor
from simglucose.simulation.env import T1DSimEnv
from simglucose.actuator.pump import InsulinPump
from simglucose.patient.t1dpatient import T1DPatient
from simglucose.simulation.sim_engine import SimObj, sim
from simglucose.simulation.scenario import CustomScenario
from simglucose.controller.basal_bolus_ctrller import BBController

from scipy.integrate import solve_ivp

# %%
import logging
logging.basicConfig()
logging.getLogger().setLevel(logging.DEBUG)

# %%
# better plots
sns.set_style('whitegrid')

# data structure for storing patient action
Action = namedtuple("patient_action", ['CHO', 'insulin'])
Observation = namedtuple("observation", ['Gsub'])

# %% [markdown]
# # inbuilt

# %%
p = T1DPatient.withName("adult#001")
basal = p._params.u2ss * p._params.BW / 6000

t = []
CHO = []
BG = []
while p.t < 1000:
    ins = basal
    carb = 0

    if p.t == 100:
        carb = 80
        ins = 80.0 / 6.0 + basal
    
    if p.t == 150:
        carb = 80
        ins = 80.0 / 12.0 + basal

    act = Action(insulin=ins, CHO=carb)
    t.append(p.t)
    CHO.append(act.CHO)
    BG.append(p.observation.Gsub)
    p.step(act)

# %%
plt.subplot(211)
plt.plot(t, CHO, label='CHO')
plt.subplot(212)
plt.plot(t, BG, label='BG')
plt.show()

# %%
data = pd.read_csv("results/adult#001.csv")

# destructure data
data_t = data["Time"].map(lambda d: dt2int(d, fmt="%Y-%m-%d %H:%M:%S.%f")).to_numpy()
data_BG = data["BG"].to_numpy()
data_CGM = data["CGM"].to_numpy()
data_CHO = data["CHO"].to_numpy()
data_insulin = data["insulin"].to_numpy()

# normalize time
data_t -= data_t[0]

# scale down to minutes
data_t = data_t / 60.0

# clean
data_CHO = np.nan_to_num(data_CHO, nan=data_CHO[0])
data_insulin = np.nan_to_num(data_insulin, nan=data_insulin[0])

# %%
plt.figure(figsize=(8, 8))
plt.subplot(311)
plt.plot(data_t, data_BG, "r")
plt.subplot(312)
plt.plot(data_t, data_CHO, "y")
plt.subplot(313)
plt.plot(data_t, data_insulin, "g")
plt.show()

# %%
CHO_times = data_t[data_CHO > data_CHO[0]]
ins_times = data_t[data_insulin > data_insulin[0]]

# %%
p = T1DPatient.withName("adult#001")
basal = p._params.u2ss * p._params.BW / 6000

t = []
CHO = []
BG = []
insr = []
while p.t < data_t[-1]:
    ins = basal
    carb = 0

    if p.t in CHO_times:
        carb = 3 * data_CHO[data_t == p.t]

    if p.t in ins_times:
        ins = 3 * data_insulin[data_t == p.t]

    act = Action(insulin=ins, CHO=carb)
    t.append(p.t)
    CHO.append(act.CHO)
    BG.append(p.observation.Gsub)
    insr.append(act.insulin)
    p.step(act)
# Out:
# INFO:simglucose.patient.t1dpatient:t = 420.0, patient starts eating ...
# DEBUG:simglucose.patient.t1dpatient:t = 420.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 421.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 422.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 423.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 423.0, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0854334916434, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.12815023746515, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.3417339665737, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.37970440730413, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.4271674582171, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.4271674582171, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0420331788428, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.06304976826425, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.16813271537126, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.1868141281903, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.2101658942141, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.2101658942141, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0266280801352, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0399421202028, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.1065123205408, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.1183470228231, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.133140400676, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.133140400676, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.01987829276067, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.029817439141, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.07951317104266, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0883479678252, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.09939146380333, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.09939146380333, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.01657529302804, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0248629395421, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0663011721123, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0736679690136, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0828764651403, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0828764651403, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.01487987524956, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.02231981287434, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.05951950099825, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0661327788869, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.07439937624775, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.07439937624775, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.08408265460633, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.08892429378557, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.113132489682, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.11743616895245, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.12281576804054, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.12281576804054, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.1392214659334, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.14742431487986, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.18843855961205, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.1957299808978, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.204844257505, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.204844257505, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.22476004738996, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.23471794233245, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.2845074170449, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.293358879216, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.30442320692987, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.30442320692987, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.33077827573015, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.3439558101303, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.409843482131, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.4215568460423, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.4361985509313, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.4361985509313, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.4690768518296, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.4855160022787, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.56771175452445, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.58232433270143, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.60059005542274, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.60059005542274, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.64138875834095, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.66178810980006, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.7637848670955, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.78191762394806, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.8045835700137, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.8045835700137, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.84366685601094, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.8632084990096, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.96091671400274, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 423.97828706333485, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 424.0, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 424.0, injecting insulin: [1.06345]
# DEBUG:simglucose.patient.t1dpatient:t = 424.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 425.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 426.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 427.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 428.0, patient eats 5 g
# INFO:simglucose.patient.t1dpatient:t = 429.0, Patient finishes eating!
# INFO:simglucose.patient.t1dpatient:t = 720.0, patient starts eating ...
# DEBUG:simglucose.patient.t1dpatient:t = 720.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 721.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 722.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 723.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 723.0, injecting insulin: [1.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 723.1040087230089, injecting insulin: [1.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 723.1560130845133, injecting insulin: [1.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 723.4160348920354, injecting insulin: [1.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 723.4622609911505, injecting insulin: [1.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 723.5200436150443, injecting insulin: [1.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 723.5200436150443, injecting insulin: [1.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 723.5989206988465, injecting insulin: [1.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 723.6383592407476, injecting insulin: [1.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 723.8355519502531, injecting insulin: [1.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 723.8706084319431, injecting insulin: [1.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 723.9144290340554, injecting insulin: [1.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 723.9144290340554, injecting insulin: [1.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 723.9315432272443, injecting insulin: [1.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 723.9401003238388, injecting insulin: [1.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 723.982885806811, injecting insulin: [1.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 723.990492114895, injecting insulin: [1.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 724.0, injecting insulin: [1.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 724.0, injecting insulin: [1.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 724.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 725.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 726.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 727.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 728.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 729.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 730.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 731.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 732.0, patient eats 5 g
# INFO:simglucose.patient.t1dpatient:t = 733.0, Patient finishes eating!
# INFO:simglucose.patient.t1dpatient:t = 960.0, patient starts eating ...
# DEBUG:simglucose.patient.t1dpatient:t = 960.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 961.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 962.0, patient eats 5 g
# INFO:simglucose.patient.t1dpatient:t = 963.0, Patient finishes eating!
# DEBUG:simglucose.patient.t1dpatient:t = 963.0, injecting insulin: [0.2605625]
# DEBUG:simglucose.patient.t1dpatient:t = 963.151765566538, injecting insulin: [0.2605625]
# DEBUG:simglucose.patient.t1dpatient:t = 963.2276483498069, injecting insulin: [0.2605625]
# DEBUG:simglucose.patient.t1dpatient:t = 963.6070622661517, injecting insulin: [0.2605625]
# DEBUG:simglucose.patient.t1dpatient:t = 963.6745136290575, injecting insulin: [0.2605625]
# DEBUG:simglucose.patient.t1dpatient:t = 963.7588278326897, injecting insulin: [0.2605625]
# DEBUG:simglucose.patient.t1dpatient:t = 963.7588278326897, injecting insulin: [0.2605625]
# DEBUG:simglucose.patient.t1dpatient:t = 963.8070622661518, injecting insulin: [0.2605625]
# DEBUG:simglucose.patient.t1dpatient:t = 963.8311794828828, injecting insulin: [0.2605625]
# DEBUG:simglucose.patient.t1dpatient:t = 963.9517655665379, injecting insulin: [0.2605625]
# DEBUG:simglucose.patient.t1dpatient:t = 963.9732030925211, injecting insulin: [0.2605625]
# DEBUG:simglucose.patient.t1dpatient:t = 964.0, injecting insulin: [0.2605625]
# DEBUG:simglucose.patient.t1dpatient:t = 964.0, injecting insulin: [0.2605625]
# INFO:simglucose.patient.t1dpatient:t = 1080.0, patient starts eating ...
# DEBUG:simglucose.patient.t1dpatient:t = 1080.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1081.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1082.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1083.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1083.0, injecting insulin: [1.34389583]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.1263420971054, injecting insulin: [1.34389583]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.189513145658, injecting insulin: [1.34389583]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.5053683884216, injecting insulin: [1.34389583]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.5615204315795, injecting insulin: [1.34389583]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.631710485527, injecting insulin: [1.34389583]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.631710485527, injecting insulin: [1.34389583]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.7053683884217, injecting insulin: [1.34389583]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.7421973398689, injecting insulin: [1.34389583]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.9263420971054, injecting insulin: [1.34389583]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.9590789428364, injecting insulin: [1.34389583]
# DEBUG:simglucose.patient.t1dpatient:t = 1084.0, injecting insulin: [1.34389583]
# DEBUG:simglucose.patient.t1dpatient:t = 1084.0, injecting insulin: [1.34389583]
# DEBUG:simglucose.patient.t1dpatient:t = 1084.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1085.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1086.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1087.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1088.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1089.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1090.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1091.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1092.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1093.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1094.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1095.0, patient eats 5 g
# INFO:simglucose.patient.t1dpatient:t = 1096.0, Patient finishes eating!
# INFO:simglucose.patient.t1dpatient:t = 1380.0, patient starts eating ...
# DEBUG:simglucose.patient.t1dpatient:t = 1380.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1381.0, patient eats 5 g
# INFO:simglucose.patient.t1dpatient:t = 1382.0, Patient finishes eating!
# DEBUG:simglucose.patient.t1dpatient:t = 1383.0, injecting insulin: [0.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 1383.2, injecting insulin: [0.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 1383.3, injecting insulin: [0.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 1383.8, injecting insulin: [0.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 1383.888888888889, injecting insulin: [0.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 1384.0, injecting insulin: [0.17722917]
# DEBUG:simglucose.patient.t1dpatient:t = 1384.0, injecting insulin: [0.17722917]

# %%
plt.figure(figsize=(8, 8))
plt.subplot(311)
plt.plot(data_t, data_BG, "r")
plt.plot(t, BG, "b")
plt.subplot(312)
plt.plot(t, CHO, "orange")
plt.subplot(313)
plt.plot(t, insr, "g")
plt.show()
# Out:
# /home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
SAMPLE_TIME = 1 # min
EAT_RATE = 5 # g/min CHO

_last_action = Action(CHO=0, insulin=0)
_last_foodtaken = 0
_is_eating = False
_planned_meal = 0

def ode(t, x, in_t, in_CHO, in_insulin, params):
    global _last_action, _is_eating, _planned_meal, _last_Qsto, _last_foodtaken

    # get current action
    t_mask = np.abs(in_t - t).argmin()
    action = Action(CHO=in_CHO[t_mask], insulin=in_insulin[t_mask])

    # basal = p._params.u2ss * p._params.BW / 6000
    # ins = basal
    # carb = 0

    # if data_CHO[t_mask] > data_CHO[0]:
    #     print(f"eating: {data_CHO[t_mask]}CHO @ {t}m")
    # carb = 3 * data_CHO[t_mask]

    # if data_insulin[t_mask] > data_insulin[0]:
    #     print(f"injecting: {data_insulin[t_mask]}u @ {t}m")
    # ins = 3 * data_insulin[t_mask]

    # action = Action(CHO=carb, insulin=ins)

    # meal = action.CHO
    # _planned_meal += meal
    # if _planned_meal > 0:
    #     to_eat = min(EAT_RATE, _planned_meal)
    #     _planned_meal -= to_eat
    #     _planned_meal = max(0, _planned_meal)
    # else:
    #     to_eat = 0

    # action = action._replace(CHO=to_eat)

    # detect eating and update last digestion amount
    # if action.CHO > 0 and _last_action.CHO <= 0:
    #     _last_Qsto = x[0] + x[1]
    #     _last_foodtaken = 0
    #     _is_eating = True

    # if _is_eating:
    #     _last_foodtaken += action.CHO # g

    # # detect eating ended
    # if action.CHO <= 0 and _last_action.CHO > 0:
    #     _is_eating = False

    # action = Action()

    # update last action
    _last_action = action

    # dynamics
    dxdt = np.zeros(13)
    d = action.CHO * 1000  # g -> mg
    insulin = action.insulin * 6000 / params.BW  # U/min -> pmol/kg/min
    basal = params.u2ss * params.BW / 6000  # U/min

    # glucose in the stomach
    qsto = x[0] + x[1]
    # NOTE: Dbar is in unit mg, hence last_foodtaken needs to be converted
    # from mg to g. See https://github.com/jxx123/simglucose/issues/41 for
    # details.
    Dbar = _last_Qsto + _last_foodtaken * 1000  # unit: mg

    # Stomach solid
    dxdt[0] = -params.kmax * x[0] + d

    if Dbar > 0:
        aa = 5 / 2 / (1 - params.b) / Dbar
        cc = 5 / 2 / params.d / Dbar
        kgut = params.kmin + (params.kmax - params.kmin) / 2 * (
            np.tanh(aa * (qsto - params.b * Dbar)) -
            np.tanh(cc * (qsto - params.d * Dbar)) + 2)
    else:
        kgut = params.kmax

    # stomach liquid
    dxdt[1] = params.kmax * x[0] - x[1] * kgut

    # intestine
    dxdt[2] = kgut * x[1] - params.kabs * x[2]

    # Rate of appearance
    Rat = params.f * params.kabs * x[2] / params.BW
    # Glucose Production
    EGPt = params.kp1 - params.kp2 * x[3] - params.kp3 * x[8]
    # Glucose Utilization
    Uiit = params.Fsnc

    # renal excretion
    if x[3] > params.ke2:
        Et = params.ke1 * (x[3] - params.ke2)
    else:
        Et = 0

    # glucose kinetics
    # plus dextrose IV injection input u[2] if needed
    dxdt[3] = max(EGPt, 0) + Rat - Uiit - Et - \
        params.k1 * x[3] + params.k2 * x[4]
    dxdt[3] = (x[3] >= 0) * dxdt[3]

    Vmt = params.Vm0 + params.Vmx * x[6]
    Kmt = params.Km0
    Uidt = Vmt * x[4] / (Kmt + x[4])
    dxdt[4] = -Uidt + params.k1 * x[3] - params.k2 * x[4]
    dxdt[4] = (x[4] >= 0) * dxdt[4]

    # insulin kinetics
    dxdt[5] = -(params.m2 + params.m4) * x[5] + params.m1 * x[9] + params.ka1 * \
        x[10] + params.ka2 * x[11]  # plus insulin IV injection u[3] if needed
    It = x[5] / params.Vi
    dxdt[5] = (x[5] >= 0) * dxdt[5]

    # insulin action on glucose utilization
    dxdt[6] = -params.p2u * x[6] + params.p2u * (It - params.Ib)

    # insulin action on production
    dxdt[7] = -params.ki * (x[7] - It)

    dxdt[8] = -params.ki * (x[8] - x[7])

    # insulin in the liver (pmol/kg)
    dxdt[9] = -(params.m1 + params.m30) * x[9] + params.m2 * x[5]
    dxdt[9] = (x[9] >= 0) * dxdt[9]

    # subcutaneous insulin kinetics
    dxdt[10] = insulin - (params.ka1 + params.kd) * x[10]
    dxdt[10] = (x[10] >= 0) * dxdt[10]

    dxdt[11] = params.kd * x[10] - params.ka2 * x[11]
    dxdt[11] = (x[11] >= 0) * dxdt[11]

    # subcutaneous glucose
    dxdt[12] = (-params.ksc * x[12] + params.ksc * x[3])
    dxdt[12] = (x[12] >= 0) * dxdt[12]

    # if action.insulin > basal:
    #     print('t = {}, injecting insulin: {}'.format(t, action.insulin))

    return dxdt

# %%
# load parameters
orig_params = pd.read_csv("../simglucose/simglucose/params/vpatient_params.csv")
params = orig_params.loc[orig_params["Name"] == "adult#001"].squeeze()

# %%
# timespan
t_span = (data_t[0], data_t[-1])
t_eval = data_t

# %%
# initial conditions
u0 = params.iloc[2:15].to_numpy()
_last_Qsto = u0[0] + u0[1]

# %%
sol = solve_ivp(ode, t_span, u0, t_eval=t_eval, args=(data_t, data_CHO, data_insulin, params))

# %%
plt.plot(sol.t, sol.y[12] / params.Vg)

# %%
plt.plot(data_CHO)
plt.show()

# %%
data_CHO_cont = []

i = 0
while i < len(data_CHO):
    if data_CHO[i] > data_CHO[0]:
        for _ in range(int(3 * data_CHO[i] / EAT_RATE)):
            data_CHO_cont.append(EAT_RATE / 6)
            i += 1
    else:
        data_CHO_cont.append(data_CHO[i])
        i += 1

data_CHO_cont = np.array(data_CHO_cont)

# %%
data_CHO_cont.shape
# Out:
# (481,)

# %%
plt.plot(data_CHO_cont, "orange")
plt.show()

# %%
data_insulin_cont = []

i = 0
while i < len(data_insulin):
    if data_insulin[i] > data_insulin[0]:
        for _ in range(int(3 * data_insulin[i])):
            data_insulin_cont.append(1 / 6)
            i += 1
    else:
        data_insulin_cont.append(data_insulin[i])
        i += 1

data_insulin_cont = np.array(data_insulin_cont)

# %%
plt.plot(data_insulin_cont, "g")
plt.show()

# %%
data_CHO_in = data_CHO / 2
data_insulin_in = data_insulin

data_insulin_in[data_insulin_in > data_insulin[0]] /= 2

# %%
sol = solve_ivp(ode, t_span, u0, t_eval=t_eval, args=(data_t, data_CHO_in, data_insulin_in, params))
plt.plot(sol.t, sol.y[12] / params.Vg)
plt.plot(data_t, data_BG, "r--")
plt.show()

# %%
def transform_cont(a, rate):
    a_cont = []

    i = 0
    while i < len(a):
        if a[i] > a[0]:
            for _ in range(int(a[i] / rate)):
                a_cont.append(rate)
                i += 1
        else:
            a_cont.append(a[i])
            i += 1

    a_cont = np.array(a_cont)

    return a

# %%
sol = solve_ivp(ode, t_span, u0, t_eval=t_eval, args=(data_t, data_CHO_cont, data_insulin_cont, params))
plt.plot(sol.t, sol.y[12] / params.Vg)
plt.plot(data_t, data_BG, "r--")
plt.show()

# %%
# plt.plot(3 * data_CHO[:200], "bo-")
plt.plot(transform_cont(data_CHO, EAT_RATE), "r")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[84], line 2
#       1 # plt.plot(3 * data_CHO[:200], "bo-")
# ----> 2 plt.plot(transform_cont(data_CHO, EAT_RATE), "r")
#       3 plt.show()
#
# Cell In[68], line 7, in transform_cont(a, rate)
#       5 while i < len(a):
#       6     if a[i] > a[0]:
# ----> 7         for _ in range(int(a[i] / rate)):
#       8             a_cont.append(rate)
#       9             i += 1
#
# KeyboardInterrupt:
