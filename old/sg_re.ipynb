# %%
from datetime import datetime, timedelta

from simglucose.simulation.scenario_gen import RandomScenario
from simglucose.controller.basal_bolus_ctrller import BBController


from simglucose.simulation.user_interface import simulate

# %%
GLOBAL_SEED = 0
START_TIME = datetime.now()

opts = dict(
    sim_time = timedelta(days=1),
    scenario = RandomScenario(start_time=START_TIME, seed=GLOBAL_SEED),
    controller = BBController(),
    patient_names = ["adult#001"],
    cgm_name = "Dexcom",
    cgm_seed = GLOBAL_SEED,
    insulin_pump_name = "Insulet",
    start_time = START_TIME,
    save_path = "results",
    animate = False,
    parallel = True,
)

# %%
x = simulate(**opts)
# Out:
# Simulation took 4.100557327270508 sec.
# /home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
