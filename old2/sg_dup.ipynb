# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from utils import dt2int

from collections import namedtuple
from datetime import timedelta, datetime

from simglucose.patient.t1dpatient import T1DPatient

from simglucose.sensor.cgm import CGMSensor
from simglucose.simulation.env import T1DSimEnv
from simglucose.actuator.pump import InsulinPump
from simglucose.patient.t1dpatient import T1DPatient
from simglucose.simulation.sim_engine import SimObj, sim
from simglucose.simulation.scenario import CustomScenario
from simglucose.controller.basal_bolus_ctrller import BBController

from scipy.integrate import solve_ivp

# %%
import logging
logging.basicConfig()
logging.getLogger().setLevel(logging.DEBUG)

# %%
# better plots
sns.set_style('whitegrid')

# data structure for storing patient action
Action = namedtuple("patient_action", ['CHO', 'insulin'])
Observation = namedtuple("observation", ['Gsub'])

# %% [markdown]
# # inbuilt

# %%
p = T1DPatient.withName("adult#001")
basal = p._params.u2ss * p._params.BW / 6000

t = []
CHO = []
BG = []
while p.t < 1000:
    ins = basal
    carb = 0

    if p.t == 100:
        carb = 80
        ins = 80.0 / 6.0 + basal
    
    if p.t == 150:
        carb = 80
        ins = 80.0 / 12.0 + basal

    act = Action(insulin=ins, CHO=carb)
    t.append(p.t)
    CHO.append(act.CHO)
    BG.append(p.observation.Gsub)
    p.step(act)
# Out:
# INFO:simglucose.patient.t1dpatient:t = 100.0, patient starts eating ...
# DEBUG:simglucose.patient.t1dpatient:t = 100.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 100.0, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.2, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.3, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.8, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.88888888888889, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 101.0, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 101.0, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.04926384524543, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.07389576786814, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.19705538098171, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.21895042331302, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.24631922622714, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.24631922622714, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.01600449159784, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.02400673739676, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.06401796639138, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.0711310737682, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.08002245798922, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.08002245798922, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.0092608163023, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.01389122445345, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.03704326520919, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.04115918356577, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.0463040815115, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.0463040815115, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.00724132177014, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.01086198265521, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.02896528708055, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.03218365231173, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.0362066088507, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.0362066088507, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.00638497174067, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.009577457611, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.02553988696268, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.02837765218075, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.03192485870335, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.03192485870335, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.03605634072014, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.03812208172853, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.0484507867705, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.05028700100019, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.05258226878729, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.05258226878729, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.05878840209034, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.06189146874186, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.07740680199949, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.0801650834675, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.08361293530254, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.08361293530254, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.09014247185333, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.09340724012871, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.10973108150569, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.11263309775048, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.11626061805646, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.11626061805646, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.12360345378912, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.12727487165543, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.14563196098706, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.14889544353491, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.15297479671972, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.15297479671972, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.16174360699246, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.16612801212884, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.1880500378107, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.1919472868208, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.19681884808344, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.19681884808344, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.20513463588253, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.20929252978208, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.2300819992798, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.23377790496829, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.2383977870789, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.2383977870789, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.24766050484389, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.25229186372638, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.27544865813886, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.27956542158996, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.28471137590385, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.28471137590385, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.29502733130289, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.30018530900242, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.3259751975, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.33056006656624, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.33629115289904, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.33629115289904, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.34846545555061, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.3545526068764, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.38498836350531, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.39039916468379, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.39716266615689, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.39716266615689, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.41318901932009, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.42120219590169, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.4612680788097, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.46839090243779, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.4772944319729, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.4772944319729, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.49124184415561, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.49821555024697, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.53308408070376, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.53928293056273, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.54703149288648, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.54703149288648, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.5604461143056, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.56715342501516, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.600689978563, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.60665203252705, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.61410459998213, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.61410459998213, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.63054162224878, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.63876013338212, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.67985268904877, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.6871580322784, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.69628971131544, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.69628971131544, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.62696659248803, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.63339758874098, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.66555257000572, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.67126901111945, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.67841456251162, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.67841456251162, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.68974131497974, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.6954046912138, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.7237215723841, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.72875568459214, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.7350483248522, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.7350483248522, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.75001318573608, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.75749561617803, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.79490776838774, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.80155881766947, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.80987262927162, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.80987262927162, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.82438565589274, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.8316421692033, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.86792473575612, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.87437496980995, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.88243776237724, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.88243776237724, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.90526036206167, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.91667166190388, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.97372816111495, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.98387153875247, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.99655076079937, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.99655076079937, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.99724060863949, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.99758553255955, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.99931015215988, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 100.99961675119992, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 101.0, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 101.0, injecting insulin: 13.354456008333258
# DEBUG:simglucose.patient.t1dpatient:t = 101.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 102.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 103.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 104.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 105.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 106.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 107.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 108.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 109.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 110.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 111.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 112.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 113.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 114.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 115.0, patient eats 5 g
# INFO:simglucose.patient.t1dpatient:t = 116.0, Patient finishes eating!
# INFO:simglucose.patient.t1dpatient:t = 150.0, patient starts eating ...
# DEBUG:simglucose.patient.t1dpatient:t = 150.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 150.0, injecting insulin: 6.687789341666592
# DEBUG:simglucose.patient.t1dpatient:t = 150.2, injecting insulin: 6.687789341666592
# DEBUG:simglucose.patient.t1dpatient:t = 150.3, injecting insulin: 6.687789341666592
# DEBUG:simglucose.patient.t1dpatient:t = 150.8, injecting insulin: 6.687789341666592
# DEBUG:simglucose.patient.t1dpatient:t = 150.88888888888889, injecting insulin: 6.687789341666592
# DEBUG:simglucose.patient.t1dpatient:t = 151.0, injecting insulin: 6.687789341666592
# DEBUG:simglucose.patient.t1dpatient:t = 151.0, injecting insulin: 6.687789341666592
# DEBUG:simglucose.patient.t1dpatient:t = 150.16485306797776, injecting insulin: 6.687789341666592
# DEBUG:simglucose.patient.t1dpatient:t = 150.24727960196665, injecting insulin: 6.687789341666592
# DEBUG:simglucose.patient.t1dpatient:t = 150.6594122719111, injecting insulin: 6.687789341666592
# DEBUG:simglucose.patient.t1dpatient:t = 150.73268030212344, injecting insulin: 6.687789341666592
# DEBUG:simglucose.patient.t1dpatient:t = 150.82426533988885, injecting insulin: 6.687789341666592
# DEBUG:simglucose.patient.t1dpatient:t = 150.82426533988885, injecting insulin: 6.687789341666592
# DEBUG:simglucose.patient.t1dpatient:t = 150.85941227191108, injecting insulin: 6.687789341666592
# DEBUG:simglucose.patient.t1dpatient:t = 150.8769857379222, injecting insulin: 6.687789341666592
# DEBUG:simglucose.patient.t1dpatient:t = 150.96485306797777, injecting insulin: 6.687789341666592
# DEBUG:simglucose.patient.t1dpatient:t = 150.98047392665433, injecting insulin: 6.687789341666592
# DEBUG:simglucose.patient.t1dpatient:t = 151.0, injecting insulin: 6.687789341666592
# DEBUG:simglucose.patient.t1dpatient:t = 151.0, injecting insulin: 6.687789341666592
# DEBUG:simglucose.patient.t1dpatient:t = 151.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 152.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 153.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 154.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 155.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 156.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 157.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 158.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 159.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 160.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 161.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 162.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 163.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 164.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 165.0, patient eats 5 g
# INFO:simglucose.patient.t1dpatient:t = 166.0, Patient finishes eating!

# %%
plt.subplot(211)
plt.plot(t, CHO, label='CHO')
plt.subplot(212)
plt.plot(t, BG, label='BG')
plt.show()
# Out:
# DEBUG:matplotlib.pyplot:Loaded backend module://matplotlib_inline.backend_inline version unknown.
# DEBUG:matplotlib.pyplot:Loaded backend module://matplotlib_inline.backend_inline version unknown.
# DEBUG:matplotlib.font_manager:findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmsy10.ttf', name='cmsy10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 2.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymBol.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymReg.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralItalic.ttf', name='STIXGeneral', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-BoldItalic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymReg.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmr10.ttf', name='cmr10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmb10.ttf', name='cmb10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBol.ttf', name='STIXGeneral', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymBol.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 2.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymReg.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUni.ttf', name='STIXNonUnicode', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansDisplay.ttf', name='DejaVu Sans Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBolIta.ttf', name='STIXGeneral', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-BoldOblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmtt10.ttf', name='cmtt10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymBol.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerifDisplay.ttf', name='DejaVu Serif Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneral.ttf', name='STIXGeneral', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Oblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFiveSymReg.ttf', name='STIXSizeFiveSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBolIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymBol.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Italic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Bold.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmex10.ttf', name='cmex10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBol.ttf', name='STIXNonUnicode', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-BoldOblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 3.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf', name='cmmi10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmss10.ttf', name='cmss10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymReg.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Oblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 3.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoMono-Regular.ttf', name='Noto Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSerif.ttf', name='FreeSerif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSans-Regular.ttf', name='Liberation Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 4.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansCondensed.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 2.25
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSerif-Italic.ttf', name='Liberation Serif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lyx/cmsy10.ttf', name='cmsy10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lyx/eufm10.ttf', name='eufm10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans-ExtraLight.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=200, stretch='normal', size='scalable')) = 2.24
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSerif-BoldItalic.ttf', name='Liberation Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-HeavyItalic.ttf', name='Lato', style='italic', variant='normal', weight=800, stretch='normal', size='scalable')) = 11.43
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_Main-Regular.otf', name='MathJax_Main', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansCondensed-Oblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=400, stretch='condensed', size='scalable')) = 3.25
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSansNarrow-BoldItalic.ttf', name='Liberation Sans Narrow', style='italic', variant='normal', weight=700, stretch='condensed', size='scalable')) = 11.535
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSans-BoldItalic.ttf', name='Liberation Sans', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 5.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Thin.ttf', name='Lato', style='normal', variant='normal', weight=200, stretch='normal', size='scalable')) = 10.24
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationMono-Bold.ttf', name='Liberation Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSans-Bold.ttf', name='Liberation Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 4.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_Vector-Regular.otf', name='MathJax_Vector', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-LightItalic.ttf', name='Lato', style='italic', variant='normal', weight=300, stretch='normal', size='scalable')) = 11.145
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationMono-Italic.ttf', name='Liberation Mono', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/droid/DroidSansFallbackFull.ttf', name='Droid Sans Fallback', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSerif-Bold.ttf', name='Liberation Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_Main-Italic.otf', name='MathJax_Main', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-BoldItalic.ttf', name='Lato', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSans.ttf', name='FreeSans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSans-Bold.ttf', name='Liberation Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 4.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerifCondensed-BoldItalic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=700, stretch='condensed', size='scalable')) = 11.535
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lyx/msam10.ttf', name='msam10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationMono-Regular.ttf', name='Liberation Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Bold.ttf', name='Lato', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansCondensed-BoldOblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=700, stretch='condensed', size='scalable')) = 3.535
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerifCondensed-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_Size1-Regular.otf', name='MathJax_Size1', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Heavy.ttf', name='Lato', style='normal', variant='normal', weight=800, stretch='normal', size='scalable')) = 10.43
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_AMS-Regular.otf', name='MathJax_AMS', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 2.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_SansSerif-Bold.otf', name='MathJax_SansSerif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_Math-Italic.otf', name='MathJax_Math', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerif-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ttf-bitstream-vera/VeraMoBd.ttf', name='Bitstream Vera Sans Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lyx/cmmi10.ttf', name='cmmi10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-BlackItalic.ttf', name='Lato', style='italic', variant='normal', weight=900, stretch='normal', size='scalable')) = 11.525
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSerif-Bold.ttf', name='Liberation Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lyx/cmr10.ttf', name='cmr10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerif.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ttf-bitstream-vera/VeraMoBI.ttf', name='Bitstream Vera Sans Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ttf-bitstream-vera/VeraIt.ttf', name='Bitstream Vera Sans', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 7.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ttf-bitstream-vera/VeraMono.ttf', name='Bitstream Vera Sans Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_WinIE6-Regular.otf', name='MathJax_WinIE6', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_WinChrome-Regular.otf', name='MathJax_WinChrome', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-SemiboldItalic.ttf', name='Lato', style='italic', variant='normal', weight=600, stretch='normal', size='scalable')) = 11.24
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationMono-Bold.ttf', name='Liberation Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ttf-bitstream-vera/VeraBI.ttf', name='Bitstream Vera Sans', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 7.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lyx/esint10.ttf', name='esint10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_Caligraphic-Regular.otf', name='MathJax_Caligraphic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSerifItalic.ttf', name='FreeSerif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSans-Italic.ttf', name='Liberation Sans', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 5.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerifCondensed-Italic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=400, stretch='condensed', size='scalable')) = 11.25
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Regular.ttf', name='Liberation Sans Narrow', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 10.25
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeMonoOblique.ttf', name='FreeMono', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSansOblique.ttf', name='FreeSans', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Medium.ttf', name='Lato', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/font-awesome/FontAwesome.otf', name='FontAwesome', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSerifBold.ttf', name='FreeSerif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationMono-Regular.ttf', name='Liberation Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuMathTeXGyre.ttf', name='DejaVu Math TeX Gyre', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSansBold.ttf', name='FreeSans', style='normal', variant='normal', weight=600, stretch='normal', size='scalable')) = 10.24
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSerif-BoldItalic.ttf', name='Liberation Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_Vector-Bold.otf', name='MathJax_Vector-Bold', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Italic.ttf', name='Liberation Sans Narrow', style='italic', variant='normal', weight=400, stretch='condensed', size='scalable')) = 11.25
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_Fraktur-Bold.otf', name='MathJax_Fraktur', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono-BoldOblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ttf-bitstream-vera/VeraSe.ttf', name='Bitstream Vera Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Regular.ttf', name='Lato', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-HairlineItalic.ttf', name='Lato', style='italic', variant='normal', weight=100, stretch='normal', size='scalable')) = 11.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-ThinItalic.ttf', name='Lato', style='italic', variant='normal', weight=200, stretch='normal', size='scalable')) = 11.24
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/font-awesome/fontawesome-webfont.ttf', name='FontAwesome', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_Math-BoldItalic.otf', name='MathJax_Math', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans-BoldOblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 3.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lyx/stmary10.ttf', name='stmary10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono-Bold.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Bold.ttf', name='Liberation Sans Narrow', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_Main-Bold.otf', name='MathJax_Main', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/openoffice/opens___.ttf', name='OpenSymbol', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationMono-BoldItalic.ttf', name='Liberation Mono', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ttf-bitstream-vera/VeraSeBd.ttf', name='Bitstream Vera Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-MediumItalic.ttf', name='Lato', style='italic', variant='normal', weight=500, stretch='normal', size='scalable')) = 11.145
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSerif-Regular.ttf', name='Liberation Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_Size3-Regular.otf', name='MathJax_Size3', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeMono.ttf', name='FreeMono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSerif-Italic.ttf', name='Liberation Serif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSerifBoldItalic.ttf', name='FreeSerif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Black.ttf', name='Lato', style='normal', variant='normal', weight=900, stretch='normal', size='scalable')) = 10.525
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerif-Italic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationMono-Italic.ttf', name='Liberation Mono', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Light.ttf', name='Lato', style='normal', variant='normal', weight=300, stretch='normal', size='scalable')) = 10.145
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSans-Italic.ttf', name='Liberation Sans', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 5.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Italic.ttf', name='Lato', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ttf-bitstream-vera/Vera.ttf', name='Bitstream Vera Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 6.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Hairline.ttf', name='Lato', style='normal', variant='normal', weight=100, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ttf-bitstream-vera/VeraMoIt.ttf', name='Bitstream Vera Sans Mono', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_SansSerif-Regular.otf', name='MathJax_SansSerif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeMonoBoldOblique.ttf', name='FreeMono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_Size2-Regular.otf', name='MathJax_Size2', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lyx/wasy10.ttf', name='wasy10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans-Oblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 3.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeMonoBold.ttf', name='FreeMono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono-Oblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lyx/msbm10.ttf', name='msbm10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerif-BoldItalic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_Caligraphic-Bold.otf', name='MathJax_Caligraphic', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_Script-Regular.otf', name='MathJax_Script', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerifCondensed.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 10.25
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_Fraktur-Regular.otf', name='MathJax_Fraktur', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lyx/cmex10.ttf', name='cmex10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ttf-bitstream-vera/VeraBd.ttf', name='Bitstream Vera Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 6.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationMono-BoldItalic.ttf', name='Liberation Mono', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_Math-Regular.otf', name='MathJax_Math', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSans-BoldItalic.ttf', name='Liberation Sans', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 5.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_Typewriter-Regular.otf', name='MathJax_Typewriter', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Semibold.ttf', name='Lato', style='normal', variant='normal', weight=600, stretch='normal', size='scalable')) = 10.24
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_SansSerif-Italic.otf', name='MathJax_SansSerif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 2.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lyx/rsfs10.ttf', name='rsfs10', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansCondensed-Bold.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 2.535
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSansBoldOblique.ttf', name='FreeSans', style='oblique', variant='normal', weight=600, stretch='normal', size='scalable')) = 11.24
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSerif-Regular.ttf', name='Liberation Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_Size4-Regular.otf', name='MathJax_Size4', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSans-Regular.ttf', name='Liberation Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 4.05
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/usr/share/fonts/truetype/elusive-icons/elusiveicons-webfont.ttf', name='elusiveicons', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# DEBUG:matplotlib.font_manager:findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('/home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 2.050000.

# %%
data = pd.read_csv("results/adult#001.csv")

# destructure data
data_t = data["Time"].map(lambda d: dt2int(d, fmt="%Y-%m-%d %H:%M:%S.%f")).to_numpy()
data_BG = data["BG"].to_numpy()
data_CGM = data["CGM"].to_numpy()
data_CHO = data["CHO"].to_numpy()
data_insulin = data["insulin"].to_numpy()

# normalize time
data_t -= data_t[0]

# scale down to minutes
data_t = data_t / 60.0

# clean
data_CHO = np.nan_to_num(data_CHO, nan=data_CHO[0])
data_insulin = np.nan_to_num(data_insulin, nan=data_insulin[0])

# %%
plt.figure(figsize=(8, 8))
plt.subplot(311)
plt.plot(data_t, data_BG, "r")
plt.subplot(312)
plt.plot(data_t, data_CHO, "y")
plt.subplot(313)
plt.plot(data_t, data_insulin, "g")
plt.show()

# %%
CHO_times = data_t[data_CHO > data_CHO[0]]
ins_times = data_t[data_insulin > data_insulin[0]]

# %%
p = T1DPatient.withName("adult#001")
basal = p._params.u2ss * p._params.BW / 6000

t = []
CHO = []
BG = []
insr = []
while p.t < data_t[-1]:
    ins = basal
    carb = 0

    if p.t in CHO_times:
        carb = 3 * data_CHO[data_t == p.t]

    if p.t in ins_times:
        ins = 3 * data_insulin[data_t == p.t]

    act = Action(insulin=ins, CHO=carb)
    t.append(p.t)
    CHO.append(act.CHO)
    BG.append(p.observation.Gsub)
    insr.append(act.insulin)
    p.step(act)
# Out:
# INFO:simglucose.patient.t1dpatient:t = 420.0, patient starts eating ...
# DEBUG:simglucose.patient.t1dpatient:t = 420.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 421.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 422.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 423.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 423.0, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0854334916434, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.12815023746515, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.3417339665737, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.37970440730413, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.4271674582171, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.4271674582171, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0420251095346, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.06303766430193, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.16810043813854, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.1867782645984, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.21012554767316, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.21012554767316, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0265828395314, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.03987425929705, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.1063313581255, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.1181459534728, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.1329141976569, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.1329141976569, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.019736556938, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.02960483540704, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.07894622775217, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.08771803083573, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0986827846902, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0986827846902, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0162689399935, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.02440340999027, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.065075759974, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0723063999711, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0813446999675, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0813446999675, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.01436539046296, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0215480856944, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.0574615618517, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.06384617983525, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.07182695231467, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.07182695231467, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.08100702095163, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.08559705527006, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.1085472268624, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.11262725736776, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.1177272954994, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.1177272954994, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.1336032737903, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.1415412629358, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.1812312086631, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.1882871990146, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.19710718695404, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.19710718695404, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.2164287087613, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.226089469665, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.27439327418324, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.2829806172087, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.2937147959905, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.2937147959905, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.31941300031843, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.3322621024824, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.3965076133022, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.40792903744796, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.42220581763013, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.42220581763013, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.45434428209944, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.47041351433404, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.5507596755073, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.56504343749367, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.5828981399766, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.5828981399766, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.62286793099565, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.6428528265052, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.74277730405294, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.760541655617, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.782747095072, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.782747095072, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.82619767605763, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.8479229665504, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.9565494190144, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 423.9758607883413, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 424.0, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 424.0, injecting insulin: [6.3807]
# DEBUG:simglucose.patient.t1dpatient:t = 424.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 425.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 426.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 427.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 428.0, patient eats 5 g
# INFO:simglucose.patient.t1dpatient:t = 429.0, Patient finishes eating!
# INFO:simglucose.patient.t1dpatient:t = 720.0, patient starts eating ...
# DEBUG:simglucose.patient.t1dpatient:t = 720.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 721.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 722.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 723.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 723.0, injecting insulin: [7.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 723.1040087445468, injecting insulin: [7.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 723.1560131168203, injecting insulin: [7.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 723.4160349781873, injecting insulin: [7.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 723.4622610868748, injecting insulin: [7.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 723.5200437227342, injecting insulin: [7.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 723.5200437227342, injecting insulin: [7.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 723.5975453694158, injecting insulin: [7.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 723.6362961927566, injecting insulin: [7.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 723.8300503094606, injecting insulin: [7.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 723.8644954857635, injecting insulin: [7.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 723.9075519561421, injecting insulin: [7.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 723.9075519561421, injecting insulin: [7.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 723.9260415649137, injecting insulin: [7.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 723.9352863692995, injecting insulin: [7.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 723.9815103912284, injecting insulin: [7.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 723.9897279951269, injecting insulin: [7.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 724.0, injecting insulin: [7.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 724.0, injecting insulin: [7.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 724.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 725.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 726.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 727.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 728.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 729.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 730.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 731.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 732.0, patient eats 5 g
# INFO:simglucose.patient.t1dpatient:t = 733.0, Patient finishes eating!
# INFO:simglucose.patient.t1dpatient:t = 960.0, patient starts eating ...
# DEBUG:simglucose.patient.t1dpatient:t = 960.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 961.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 962.0, patient eats 5 g
# INFO:simglucose.patient.t1dpatient:t = 963.0, Patient finishes eating!
# DEBUG:simglucose.patient.t1dpatient:t = 963.0, injecting insulin: [1.563375]
# DEBUG:simglucose.patient.t1dpatient:t = 963.1517537043322, injecting insulin: [1.563375]
# DEBUG:simglucose.patient.t1dpatient:t = 963.2276305564984, injecting insulin: [1.563375]
# DEBUG:simglucose.patient.t1dpatient:t = 963.6070148173291, injecting insulin: [1.563375]
# DEBUG:simglucose.patient.t1dpatient:t = 963.6744609081434, injecting insulin: [1.563375]
# DEBUG:simglucose.patient.t1dpatient:t = 963.7587685216613, injecting insulin: [1.563375]
# DEBUG:simglucose.patient.t1dpatient:t = 963.7587685216613, injecting insulin: [1.563375]
# DEBUG:simglucose.patient.t1dpatient:t = 963.807014817329, injecting insulin: [1.563375]
# DEBUG:simglucose.patient.t1dpatient:t = 963.831137965163, injecting insulin: [1.563375]
# DEBUG:simglucose.patient.t1dpatient:t = 963.9517537043323, injecting insulin: [1.563375]
# DEBUG:simglucose.patient.t1dpatient:t = 963.9731965024068, injecting insulin: [1.563375]
# DEBUG:simglucose.patient.t1dpatient:t = 964.0, injecting insulin: [1.563375]
# DEBUG:simglucose.patient.t1dpatient:t = 964.0, injecting insulin: [1.563375]
# INFO:simglucose.patient.t1dpatient:t = 1080.0, patient starts eating ...
# DEBUG:simglucose.patient.t1dpatient:t = 1080.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1081.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1082.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1083.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1083.0, injecting insulin: [8.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.1264020939075, injecting insulin: [8.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.1896031408612, injecting insulin: [8.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.50560837563, injecting insulin: [8.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.5617870840333, injecting insulin: [8.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.6320104695374, injecting insulin: [8.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.6320104695374, injecting insulin: [8.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.70560837563, injecting insulin: [8.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.742407328676, injecting insulin: [8.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.9264020939074, injecting insulin: [8.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 1083.959112274393, injecting insulin: [8.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 1084.0, injecting insulin: [8.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 1084.0, injecting insulin: [8.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 1084.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1085.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1086.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1087.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1088.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1089.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1090.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1091.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1092.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1093.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1094.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1095.0, patient eats 5 g
# INFO:simglucose.patient.t1dpatient:t = 1096.0, Patient finishes eating!
# INFO:simglucose.patient.t1dpatient:t = 1380.0, patient starts eating ...
# DEBUG:simglucose.patient.t1dpatient:t = 1380.0, patient eats 5 g
# DEBUG:simglucose.patient.t1dpatient:t = 1381.0, patient eats 5 g
# INFO:simglucose.patient.t1dpatient:t = 1382.0, Patient finishes eating!
# DEBUG:simglucose.patient.t1dpatient:t = 1383.0, injecting insulin: [1.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 1383.2, injecting insulin: [1.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 1383.3, injecting insulin: [1.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 1383.8, injecting insulin: [1.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 1383.888888888889, injecting insulin: [1.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 1384.0, injecting insulin: [1.063375]
# DEBUG:simglucose.patient.t1dpatient:t = 1384.0, injecting insulin: [1.063375]

# %%
plt.figure(figsize=(8, 8))
plt.subplot(311)
plt.plot(data_t, data_BG, "r")
plt.plot(t, BG, "b")
plt.subplot(312)
plt.plot(t, CHO, "orange")
plt.subplot(313)
plt.plot(t, insr, "g")
plt.show()
# Out:
# /home2/vishva.saravanan/miniconda3/envs/v/lib/python3.10/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
SAMPLE_TIME = 1 # min
EAT_RATE = 5 # g/min CHO

_last_action = Action(CHO=0, insulin=0)
_last_foodtaken = 0
_is_eating = False
_planned_meal = 0

def ode(t, x, in_t, in_CHO, in_insulin, params):
    global _last_action, _is_eating, _planned_meal, _last_Qsto, _last_foodtaken

    # get current action
    t_mask = np.abs(in_t - t).argmin()
    action = Action(CHO=in_CHO[t_mask], insulin=in_insulin[t_mask])

    # basal = p._params.u2ss * p._params.BW / 6000
    # ins = basal
    # carb = 0

    # if data_CHO[t_mask] > data_CHO[0]:
    #     print(f"eating: {data_CHO[t_mask]}CHO @ {t}m")
    # carb = 3 * data_CHO[t_mask]

    # if data_insulin[t_mask] > data_insulin[0]:
    #     print(f"injecting: {data_insulin[t_mask]}u @ {t}m")
    # ins = 3 * data_insulin[t_mask]

    # action = Action(CHO=carb, insulin=ins)

    # meal = action.CHO
    # _planned_meal += meal
    # if _planned_meal > 0:
    #     to_eat = min(EAT_RATE, _planned_meal)
    #     _planned_meal -= to_eat
    #     _planned_meal = max(0, _planned_meal)
    # else:
    #     to_eat = 0

    # action = action._replace(CHO=to_eat)

    # detect eating and update last digestion amount
    # if action.CHO > 0 and _last_action.CHO <= 0:
    #     _last_Qsto = x[0] + x[1]
    #     _last_foodtaken = 0
    #     _is_eating = True

    # if _is_eating:
    #     _last_foodtaken += action.CHO # g

    # # detect eating ended
    # if action.CHO <= 0 and _last_action.CHO > 0:
    #     _is_eating = False

    # action = Action()

    # update last action
    _last_action = action

    # dynamics
    dxdt = np.zeros(13)
    d = action.CHO * 1000  # g -> mg
    insulin = action.insulin * 6000 / params.BW  # U/min -> pmol/kg/min
    basal = params.u2ss * params.BW / 6000  # U/min

    # glucose in the stomach
    qsto = x[0] + x[1]
    # NOTE: Dbar is in unit mg, hence last_foodtaken needs to be converted
    # from mg to g. See https://github.com/jxx123/simglucose/issues/41 for
    # details.
    Dbar = _last_Qsto + _last_foodtaken * 1000  # unit: mg

    # Stomach solid
    dxdt[0] = -params.kmax * x[0] + d

    if Dbar > 0:
        aa = 5 / 2 / (1 - params.b) / Dbar
        cc = 5 / 2 / params.d / Dbar
        kgut = params.kmin + (params.kmax - params.kmin) / 2 * (
            np.tanh(aa * (qsto - params.b * Dbar)) -
            np.tanh(cc * (qsto - params.d * Dbar)) + 2)
    else:
        kgut = params.kmax

    # stomach liquid
    dxdt[1] = params.kmax * x[0] - x[1] * kgut

    # intestine
    dxdt[2] = kgut * x[1] - params.kabs * x[2]

    # Rate of appearance
    Rat = params.f * params.kabs * x[2] / params.BW
    # Glucose Production
    EGPt = params.kp1 - params.kp2 * x[3] - params.kp3 * x[8]
    # Glucose Utilization
    Uiit = params.Fsnc

    # renal excretion
    if x[3] > params.ke2:
        Et = params.ke1 * (x[3] - params.ke2)
    else:
        Et = 0

    # glucose kinetics
    # plus dextrose IV injection input u[2] if needed
    dxdt[3] = max(EGPt, 0) + Rat - Uiit - Et - \
        params.k1 * x[3] + params.k2 * x[4]
    dxdt[3] = (x[3] >= 0) * dxdt[3]

    Vmt = params.Vm0 + params.Vmx * x[6]
    Kmt = params.Km0
    Uidt = Vmt * x[4] / (Kmt + x[4])
    dxdt[4] = -Uidt + params.k1 * x[3] - params.k2 * x[4]
    dxdt[4] = (x[4] >= 0) * dxdt[4]

    # insulin kinetics
    dxdt[5] = -(params.m2 + params.m4) * x[5] + params.m1 * x[9] + params.ka1 * \
        x[10] + params.ka2 * x[11]  # plus insulin IV injection u[3] if needed
    It = x[5] / params.Vi
    dxdt[5] = (x[5] >= 0) * dxdt[5]

    # insulin action on glucose utilization
    dxdt[6] = -params.p2u * x[6] + params.p2u * (It - params.Ib)

    # insulin action on production
    dxdt[7] = -params.ki * (x[7] - It)

    dxdt[8] = -params.ki * (x[8] - x[7])

    # insulin in the liver (pmol/kg)
    dxdt[9] = -(params.m1 + params.m30) * x[9] + params.m2 * x[5]
    dxdt[9] = (x[9] >= 0) * dxdt[9]

    # subcutaneous insulin kinetics
    dxdt[10] = insulin - (params.ka1 + params.kd) * x[10]
    dxdt[10] = (x[10] >= 0) * dxdt[10]

    dxdt[11] = params.kd * x[10] - params.ka2 * x[11]
    dxdt[11] = (x[11] >= 0) * dxdt[11]

    # subcutaneous glucose
    dxdt[12] = (-params.ksc * x[12] + params.ksc * x[3])
    dxdt[12] = (x[12] >= 0) * dxdt[12]

    # if action.insulin > basal:
    #     print('t = {}, injecting insulin: {}'.format(t, action.insulin))

    return dxdt

# %%
# load parameters
orig_params = pd.read_csv("../simglucose/simglucose/params/vpatient_params.csv")
params = orig_params.loc[orig_params["Name"] == "adult#001"].squeeze()

# %%
# timespan
t_span = (data_t[0], data_t[-1])
t_eval = data_t

# %%
# initial conditions
u0 = params.iloc[2:15].to_numpy()
_last_Qsto = u0[0] + u0[1]

# %%
sol = solve_ivp(ode, t_span, u0, t_eval=t_eval, args=(data_t, data_CHO, data_insulin, params))

# %%
plt.plot(sol.t, sol.y[12] / params.Vg)

# %%
plt.plot(data_CHO)
plt.show()

# %%
data_CHO_cont = []

i = 0
while i < len(data_CHO):
    if data_CHO[i] > data_CHO[0]:
        for _ in range(int(3 * data_CHO[i] / EAT_RATE)):
            data_CHO_cont.append(EAT_RATE / 6)
            i += 1
    else:
        data_CHO_cont.append(data_CHO[i])
        i += 1

data_CHO_cont = np.array(data_CHO_cont)

# %%
data_CHO_cont.shape
# Out:
# (481,)

# %%
plt.plot(data_CHO_cont, "orange")
plt.show()

# %%
data_insulin_cont = []

i = 0
while i < len(data_insulin):
    if data_insulin[i] > data_insulin[0]:
        for _ in range(int(3 * data_insulin[i])):
            data_insulin_cont.append(1 / 6)
            i += 1
    else:
        data_insulin_cont.append(data_insulin[i])
        i += 1

data_insulin_cont = np.array(data_insulin_cont)

# %%
plt.plot(data_insulin_cont, "g")
plt.show()

# %%
data_CHO_in = data_CHO / 2
data_insulin_in = data_insulin

data_insulin_in[data_insulin_in > data_insulin[0]] /= 2

# %%
sol = solve_ivp(ode, t_span, u0, t_eval=t_eval, args=(data_t, data_CHO_in, data_insulin_in, params))
plt.plot(sol.t, sol.y[12] / params.Vg)
plt.plot(data_t, data_BG, "r--")
plt.show()

# %%
def transform_cont(a, rate):
    a_cont = []

    i = 0
    while i < len(a):
        if a[i] > a[0]:
            for _ in range(int(a[i] / rate)):
                a_cont.append(rate)
                i += 1
        else:
            a_cont.append(a[i])
            i += 1

    a_cont = np.array(a_cont)

    return a

# %%
proc_insulin = np.where(data_insulin_cont > data_insulin_cont[0], data_insulin_cont, data_insulin_cont)
sol = solve_ivp(ode, t_span, u0, t_eval=t_eval, args=(data_t, data_CHO_cont, proc_insulin, params))
plt.plot(sol.t, sol.y[12] / params.Vg)
plt.plot(data_t, data_BG, "r--")
plt.show()
